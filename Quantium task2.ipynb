# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('QVI_data.csv')
data
# Out:
#         LYLTY_CARD_NBR   DATE  STORE_NBR  LYLTY_CARD_NBR.1  TXN_ID  PROD_NBR  \
# 0               1000.0  43390          1              1000       1         5
# 1               1002.0  43599          1              1307     348        66
# 2               1003.0  43605          1              1343     383        61
# 3               1004.0  43329          2              2373     974        69
# 4               1005.0  43330          2              2426    1038       108
# ...                ...    ...        ...               ...     ...       ...
# 264831             NaN  43533        272            272319  270088        89
# 264832             NaN  43325        272            272358  270154        74
# 264833             NaN  43410        272            272379  270187        51
# 264834             NaN  43461        272            272379  270188        42
# 264835             NaN  43365        272            272380  270189        74
#
# ...

# %%
data.head()
# Out:
#    LYLTY_CARD_NBR   DATE  STORE_NBR  LYLTY_CARD_NBR.1  TXN_ID  PROD_NBR  \
# 0          1000.0  43390          1              1000       1         5
# 1          1002.0  43599          1              1307     348        66
# 2          1003.0  43605          1              1343     383        61
# 3          1004.0  43329          2              2373     974        69
# 4          1005.0  43330          2              2426    1038       108
#
#                                   PROD_NAME  PROD_QTY  TOT_SALES  \
# 0    Natural Chip        Compny SeaSalt175g         2        6.0
# 1                  CCs Nacho Cheese    175g         3        6.3
# 2    Smiths Crinkle Cut  Chips Chicken 170g         2        2.9
# 3    Smiths Chip Thinly  S/Cream&Onion 175g         5       15.0
# 4  Kettle Tortilla ChpsHny&Jlpno Chili 150g         3       13.8
#
#                 LIFESTAGE PREMIUM_CUSTOMER
# 0   YOUNG SINGLES/COUPLES          Premium
# 1   YOUNG SINGLES/COUPLES       Mainstream
# ...

# %%
total_sales=sum(data['TOT_SALES'])
print(total_sales)
# Out:
# 1934414.999999633

# %%
data.describe()
# Out:
#        LYLTY_CARD_NBR           DATE     STORE_NBR  LYLTY_CARD_NBR.1  \
# count    7.263700e+04  264836.000000  264836.00000      2.648360e+05
# mean     1.361859e+05   43464.036260     135.08011      1.355495e+05
# std      8.989293e+04     105.389282      76.78418      8.057998e+04
# min      1.000000e+03   43282.000000       1.00000      1.000000e+03
# 25%      6.620200e+04   43373.000000      70.00000      7.002100e+04
# 50%      1.340400e+05   43464.000000     130.00000      1.303575e+05
# 75%      2.033750e+05   43555.000000     203.00000      2.030942e+05
# max      2.373711e+06   43646.000000     272.00000      2.373711e+06
#
#              TXN_ID       PROD_NBR       PROD_QTY      TOT_SALES
# count  2.648360e+05  264836.000000  264836.000000  264836.000000
# mean   1.351583e+05      56.583157       1.907309       7.304200
# std    7.813303e+04      32.826638       0.643654       3.083226
# min    1.000000e+00       1.000000       1.000000       1.500000
# ...

# %%
total_customer=241584

# %%
data.shape
# Out:
# (264836, 11)

# %%
total_customer=241584
transaction=264834
avg_transaction=total=total_customer/transaction
print(avg_transaction)
# Out:
# 0.9122091574344684
